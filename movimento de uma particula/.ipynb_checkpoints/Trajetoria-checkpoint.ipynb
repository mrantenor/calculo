# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt
from sympy.vector import CoordSys3D

# %%
def mod(vector):
    tamanho = sp.simplify(sp.sqrt(sp.vector.dot(vector,vector)))
    return tamanho

# %%
C = CoordSys3D('C')
t = sp.symbols('t')

r = t**3*C.i+t**2*C.j+0*C.k
r_1 = sp.diff(r,t)

T = r_1/mod(r_1)
T_1 = sp.diff(T,t)

N = T_1/mod(T_1)
B = sp.simplify(sp.vector.cross(T,N))

# %%
############### FUNÇÃO ################
rx = sp.lambdify(t, r.dot(C.i), 'numpy')
ry = sp.lambdify(t, r.dot(C.j), 'numpy')
rz = sp.lambdify(t, r.dot(C.k), 'numpy')

################# T ###################
Tx = sp.lambdify(t, T.dot(C.i), 'numpy')
Ty = sp.lambdify(t, T.dot(C.j), 'numpy')
Tz = sp.lambdify(t, T.dot(C.k), 'numpy')

################# N ###################
Nx = sp.lambdify(t, N.dot(C.i), 'numpy')
Ny = sp.lambdify(t, N.dot(C.j), 'numpy')
Nz = sp.lambdify(t, N.dot(C.k), 'numpy')

################# B ###################
Bx = sp.lambdify(t, B.dot(C.i), 'numpy')
By = sp.lambdify(t, B.dot(C.j), 'numpy')
Bz = sp.lambdify(t, B.dot(C.k), 'numpy')

# %%
t_vals = np.linspace(0, 50, 50)
t_vals_n = np.arange(0, 50, 1)
t_point = 3*np.pi

# %%
for i_,n_ in zip(t_vals,t_vals_n):
    ax = plt.axes(projection='3d')
    ax.plot(rx(t_vals),ry(t_vals),rz(t_vals),linewidth=1)
    ax.scatter(rx(i_),ry(i_),rz(i_),c='orange')
    ax.quiver(rx(i_),ry(i_),rz(i_),Tx(i_),Ty(i_),Tz(i_),color='blue',linewidth=1.2)
    ax.quiver(rx(i_),ry(i_),rz(i_),Nx(i_),Ny(i_),Nz(i_),color='red',linewidth=1.2)
    ax.quiver(rx(i_),ry(i_),rz(i_),Bx(i_),By(i_),Bz(i_),color='green',linewidth=1.2)
    plt.savefig('/home/antenor/Documents/IC/b/'+str(n_)+'.png')
# Out:
# <lambdifygenerated-4>:2: RuntimeWarning: invalid value encountered in scalar divide
#   return 3*t**2/sqrt(t**2*(9*t**2 + 4))
# <lambdifygenerated-5>:2: RuntimeWarning: invalid value encountered in scalar divide
#   return 2*t/sqrt(t**2*(9*t**2 + 4))
# <lambdifygenerated-7>:2: RuntimeWarning: invalid value encountered in scalar divide
#   return (1/6)*(6*t/sqrt(t**2*(9*t**2 + 4)) + 3*(-9*t**3 - t*(9*t**2 + 4))/(sqrt(t**2*(9*t**2 + 4))*(9*t**2 + 4)))/sqrt((9*t**2 + 4)**(-2.0))
# <lambdifygenerated-8>:2: RuntimeWarning: divide by zero encountered in scalar divide
#   return (1/6)*(2/sqrt(t**2*(9*t**2 + 4)) + 2*(-9*t**3 - t*(9*t**2 + 4))/(t*sqrt(t**2*(9*t**2 + 4))*(9*t**2 + 4)))/sqrt((9*t**2 + 4)**(-2.0))
# <lambdifygenerated-8>:2: RuntimeWarning: invalid value encountered in scalar divide
#   return (1/6)*(2/sqrt(t**2*(9*t**2 + 4)) + 2*(-9*t**3 - t*(9*t**2 + 4))/(t*sqrt(t**2*(9*t**2 + 4))*(9*t**2 + 4)))/sqrt((9*t**2 + 4)**(-2.0))
# ...
